# %% [markdown]
# <a href="https://colab.research.google.com/github/FOFM030711/Caminata-aleatoria-1D/blob/main/SISTEMA_DE_LINEA_DE_ESPERA_simu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SIMULACION SHELDON ROSS
# **Sección 6.2. Sistame de línea de espera con un servidor (pág. 88-90)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *  $t$= Tiempo
# * $N_A$= Número de llegadas
# * $N_D$=Número de salidas
# Eventos:
#
#
# 1.  $t_A$= Tiempo de la siguiente llegada
#
#
#
#
# 2.  $t_D$= Tiempo de la siguiente salida
#
#
#
# Queremos:
#
# a) Tiempo promedio de un cliente en el sistema
#
# b) Tiempo en el que sale el último cliente
#
#
#
# * Generar $T_0$ → $U$∼$U(0,1)$
#   $t=t-\frac{1}{λ}logU$
#
#   $t_A=T_0$
#
#   $t_D=∞$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math
