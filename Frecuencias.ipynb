# %% [markdown]
# <a href="https://colab.research.google.com/github/FOFM030711/Caminata-aleatoria-1D/blob/main/Frecuencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prueba de Frecuencias  para números aleatorios

# %%
import numpy as np #esta libereria es para hacer calculos númericos
from scipy.stats import norm
import scipy.stats as st

# %%
numeros = [
    [0.78961, 0.05230, 0.10689, 0.55877, 0.14151],
    [0.76086, 0.12079, 0.27738, 0.65726, 0.79269],
    [0.80548, 0.82654, 0.29453, 0.20852, 0.42989],
    [0.58518, 0.98611, 0.34488, 0.34358, 0.11537],
    [0.89898, 0.57880, 0.67621, 0.05010, 0.00121],
    [0.28269, 0.73059, 0.70119, 0.18284, 0.49962],
    [0.38618, 0.76910, 0.68834, 0.55170, 0.10850],
    [0.79982, 0.45679, 0.21631, 0.87616, 0.55743],
    [0.58962, 0.33216, 0.03185, 0.61168, 0.09264],
    [0.69823, 0.17028, 0.05475, 0.91512, 0.76262],
    [0.29931, 0.30861, 0.83358, 0.51781, 0.03272],
    [0.57410, 0.26593, 0.85903, 0.48338, 0.35288],
    [0.24000, 0.65559, 0.38507, 0.90829, 0.94187],
    [0.93655, 0.88809, 0.81772, 0.36982, 0.19904],
    [0.54325, 0.62400, 0.09133, 0.41678, 0.33954],
    [0.58244, 0.85853, 0.88752, 0.38729, 0.15506],
    [0.23949, 0.53559, 0.33881, 0.49883, 0.75103],
    [0.19962, 0.65002, 0.74579, 0.79113, 0.63453],
    [0.19147, 0.40644, 0.08128, 0.73435, 0.22724],
    [0.22287, 0.07281, 0.64183, 0.44267, 0.72102]
]

# %% [markdown]
# Aplicamos la prueba de estadisticos

# %%
# Aplanar la lista de listas en una sola lista
datos_de_numeros = [item for sublista in numeros for item in sublista]

# %% [markdown]
# Obtener el número de muestras y la media muestral

# %%
N = len(datos_de_numeros)
x_bar = np.mean(datos_de_numeros)

# %% [markdown]
# Es la media de la muestra

# %%
x_bar
# Out:
# np.float64(0.483516)

# %% [markdown]
#  Calcular el estadístico $Z_0$ utilizando la fórmula proporcionada
#  $Z_0=\frac{\bar{x}-\frac{1}{2}\sqrt{N}}{\sqrt{\frac{1}{12}}}$

# %%
# The correct formula for Z-statistic for mean of U(0,1) is:
# Z = (x_bar - 0.5) * np.sqrt(N) / np.sqrt(1/12)
Z0 = (x_bar - 0.5) * np.sqrt(N) / np.sqrt(1/12)

# %%
Z0
# Out:
# np.float64(-0.5710225102393075)

# %% [markdown]
# Definir el nivel de significancia (alpha)

# %%
alpha = 0.05 # Nivel de significancia comúnmente utilizado

# %% [markdown]
# Calcular el valor crítico de Z para una prueba de dos colas

# %%
z_critico = norm.ppf(1 - alpha/2)

resultados_prueba = []
resultados_prueba.append(f"Número de muestras (N): {N}")
resultados_prueba.append(f"Media muestral (x̄): {x_bar:.4f}")
resultados_prueba.append(f"Estadístico Z calculado (Z0): {Z0:.4f}")
resultados_prueba.append(f"Nivel de significancia (α): {alpha}")
resultados_prueba.append(f"Valor Z crítico (Z_α/2): {z_critico:.4f}")

# %% [markdown]
#  Realizar la prueba de hipótesis
#
#  * HIPOTESIS NULA:
# $$H_o: μ=0.5 = \frac{1}{2}$$
# * HIPOTESIS ALTERNATIVA:
# $$ H_A:μ \neq 0.5 = \frac{1}{2}$$

# %%
if abs(Z0) < z_critico:
    resultados_prueba.append(f"\nDado que $|Z_0|$ ({abs(Z0):.4f}) < Z_crítico ({z_critico:.4f}), NO RECHAZAMOS la hipótesis nula.")
    resultados_prueba.append("Esto sugiere que la media de los números generados no es significativamente diferente de 0.5.")
else:
    resultados_prueba.append(f"\nDado que $|Z_0|$ ({abs(Z0):.4f}) >= Z_crítico ({z_critico:.4f}), RECHAZAMOS la hipótesis nula.")
    resultados_prueba.append("Esto sugiere que la media de los números generados es significativamente diferente de 0.5.")

# %%
# Imprimir los resultados
print('\n'.join(resultados_prueba))
# Out:
# Número de muestras (N): 100
# Media muestral (x̄): 0.4835
# Estadístico Z calculado (Z0): -0.5710
# Nivel de significancia (α): 0.05
# Valor Z crítico (Z_α/2): 1.9600
#
# Dado que $|Z_0|$ (0.5710) < Z_crítico (1.9600), NO RECHAZAMOS la hipótesis nula.
# Esto sugiere que la media de los números generados no es significativamente diferente de 0.5.

# %% [markdown]
# A continuacion se procedera a calcular el promedio

# %%
def promedio(numeros, alfa):

  x= np.mean(numeros)
  N=len(numeros)

  z=(x-0.5)*np.sqrt(N)/np.sqrt(1/12)

  z_c = st.norm.ppf(1-alfa/2)

  if abs(z)<z_c:
    print("No se rechaza H_0: La muestra proviene de una dsitribución U(0,1)" )
  else:
    print("SE rechaza H_0: La muestra proviene de una dsitribución U(0,1)")
promedio(datos_de_numeros, 0.05)
print(np.mean(datos_de_numeros))
# Out:
# No se rechaza H_0: La muestra proviene de una dsitribución U(0,1)
# 0.483516

# %% [markdown]
#  Se calcula la media muestral $\bar{x}$ y el tamaño $N$.
#
#  Bajo $H_0: X \sim U(0,1)$, se tiene $\mathbb{E}(X)=0.5$ y $\mathrm{Var}(X)=\frac{1}{2}$.
#
# Se construye el estadístico
#
#  $$Z = \frac{(\bar{x}-0.5)\sqrt{N}}{\sqrt{1/12}}$$,
#  que bajo $H_0$ sigue aproximadamente una $N(0,1)$.
#  Se compara |Z| con el valor crítico $z_{1-\frac{\alpha}{2}}$;
#  si $|Z|<z_{1-\frac{\alpha}{2}}$no se rechaza $H_0$, en otro caso se rechaza.
#  Finalmente se imprime la media muestral.

# %%
z_critico = norm.ppf(1 - alpha/2)

resultados_prueba = []
resultados_prueba.append(f"Número de muestras (N): {N}")
resultados_prueba.append(f"Media muestral (x̄): {x_bar:.4f}")
resultados_prueba.append(f"Estadístico Z calculado (Z0): {Z0:.4f}")
resultados_prueba.append(f"Nivel de significancia (α): {alpha}")
resultados_prueba.append(f"Valor Z crítico (Z_α/2): {z_critico:.4f}")

# %%
if abs(Z0) < z_critico:
    resultados_prueba.append(f"\nDado que $|Z_0|$ ({abs(Z0):.4f}) < Z_crítico ({z_critico:.4f}), NO RECHAZAMOS la hipótesis nula.")
    resultados_prueba.append("Esto sugiere que la media de los números generados no es significativamente diferente de 0.5.")
else:
    resultados_prueba.append(f"\nDado que $|Z_0|$ ({abs(Z0):.4f}) >= Z_crítico ({z_critico:.4f}), RECHAZAMOS la hipótesis nula.")
    resultados_prueba.append("Esto sugiere que la media de los números generados es significativamente diferente de 0.5.")

# %%
# Imprimir los resultados
print('\n'.join(resultados_prueba))
# Out:
# Número de muestras (N): 100
# Media muestral (x̄): 0.4835
# Estadístico Z calculado (Z0): -0.5710
# Nivel de significancia (α): 0.05
# Valor Z crítico (Z_α/2): 1.9600
#
# Dado que $|Z_0|$ (0.5710) < Z_crítico (1.9600), NO RECHAZAMOS la hipótesis nula.
# Esto sugiere que la media de los números generados no es significativamente diferente de 0.5.

# %% [markdown]
# Clasificamos

# %%
bins = [0, 0.2, 0.4, 0.6, 0.8, 1.01]

# Clasificar datos en intervalos
indices = np.digitize(datos_de_numeros, bins, right=False)

# Contar cuántos hay en cada intervalo
conteos = [(indices == i).sum() for i in range(1, len(bins))]

print(conteos)
# Out:
# [np.int64(21), np.int64(22), np.int64(19), np.int64(23), np.int64(15)]

# %% [markdown]
# A continucacion procedemos a realizar nuestros calculos

# %%
import pandas as pd
import numpy as np

bins = [0, 0.2, 0.4, 0.6, 0.8, 1.01]

# Clasificar datos en intervalos
indices = np.digitize(datos_de_numeros, bins, right=False)

# Contar cuántos hay en cada intervalo
conteos = [(indices == i).sum() for i in range(1, len(bins))]

# Total de datos
n = len(datos_de_numeros)
k = len(bins) - 1

# Frecuencia esperada
FE = n / k

# Frecuencia observada
frecuencia = np.array(conteos)

# Frecuencia acumulada
frecuencia_acum = np.cumsum(frecuencia)

# Frecuencia relativa
frecuencia_rel = frecuencia / n

# Frecuencia relativa acumulada
frecuencia_rel_acum = np.cumsum(frecuencia_rel)

# Marcas de clase
marcas_clase = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins)-1)]

# Cálculos chi-cuadrada
fi_menos_FE = frecuencia - FE
cuadrado = fi_menos_FE**2
chi_individual = cuadrado / FE

chi_total = chi_individual.sum()

# Crear tabla
tabla = pd.DataFrame({
    "Intervalo": [f"[{bins[i]} - {bins[i+1]})" for i in range(len(bins)-1)],
    "Marca de clase (xi)": marcas_clase,
    "Frecuencia (fi)": frecuencia,
    "Frecuencia acumulada (Fi)": frecuencia_acum,
    "Frecuencia relativa (hi)": frecuencia_rel,
    "Frecuencia relativa acumulada (Hi)": frecuencia_rel_acum,
    "FE": FE,
    "fi - FE": fi_menos_FE,
    "(fi - FE)^2": cuadrado,
    "(fi - FE)^2 / FE": chi_individual
})

print(tabla)
print("\nEstadístico Chi-cuadrada total:", chi_total)
# Out:
#       Intervalo  Marca de clase (xi)  Frecuencia (fi)  \
# 0     [0 - 0.2)                0.100               21
# 1   [0.2 - 0.4)                0.300               22
# 2   [0.4 - 0.6)                0.500               19
# 3   [0.6 - 0.8)                0.700               23
# 4  [0.8 - 1.01)                0.905               15
#
#    Frecuencia acumulada (Fi)  Frecuencia relativa (hi)  \
# 0                         21                      0.21
# 1                         43                      0.22
# 2                         62                      0.19
# 3                         85                      0.23
# 4                        100                      0.15
#
#    Frecuencia relativa acumulada (Hi)    FE  fi - FE  (fi - FE)^2  \
# 0                                0.21  20.0      1.0          1.0
# 1                                0.43  20.0      2.0          4.0
# 2                                0.62  20.0     -1.0          1.0
# 3                                0.85  20.0      3.0          9.0
# 4                                1.00  20.0     -5.0         25.0
#
#    (fi - FE)^2 / FE
# 0              0.05
# 1              0.20
# 2              0.05
# 3              0.45
# 4              1.25
#
# Estadístico Chi-cuadrada total: 2.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datos (asegúrate de tener tu lista datos_de_numeros)
datos = datos_de_numeros

# Intervalos
bins = [0, 0.2, 0.4, 0.6, 0.8, 1.01]

# Clasificar datos en intervalos
indices = np.digitize(datos, bins, right=False)

# Contar cuántos hay en cada intervalo
frecuencia = np.array([(indices == i).sum() for i in range(1, len(bins))])

# Total de datos
n = len(datos)
k = len(bins) - 1

# Frecuencia esperada
FE = n / k

# Frecuencia acumulada
frecuencia_acum = np.cumsum(frecuencia)

# Frecuencia relativa
frecuencia_rel = frecuencia / n

# Frecuencia relativa acumulada
frecuencia_rel_acum = np.cumsum(frecuencia_rel)

# Marcas de clase
marcas_clase = [(bins[i] + bins[i+1]) / 2 for i in range(len(bins)-1)]

# Cálculo chi-cuadrada (solo resultado final por clase)
chi_individual = (frecuencia - FE)**2 / FE
chi_total = chi_individual.sum()

# Crear tabla SIN (fi - FE) ni (fi - FE)^2
tabla = pd.DataFrame({
    "Intervalo": [f"[{bins[i]} - {bins[i+1]})" for i in range(len(bins)-1)],
    "Marca de clase (xi)": marcas_clase,
    "Frecuencia observada (fi)": frecuencia,
    "Frecuencia esperada (FE)": [FE]*k,
    "Frecuencia acumulada (Fi)": frecuencia_acum,
    "Frecuencia relativa (hi)": frecuencia_rel,
    "Frecuencia relativa acumulada (Hi)": frecuencia_rel_acum,
    "(fi - FE)^2 / FE": chi_individual
})

# %%
print(tabla)
print("\nEstadístico Chi-cuadrada total:", chi_total)
# Out:
#       Intervalo  Marca de clase (xi)  Frecuencia observada (fi)  \
# 0     [0 - 0.2)                0.100                         21
# 1   [0.2 - 0.4)                0.300                         22
# 2   [0.4 - 0.6)                0.500                         19
# 3   [0.6 - 0.8)                0.700                         23
# 4  [0.8 - 1.01)                0.905                         15
#
#    Frecuencia esperada (FE)  Frecuencia acumulada (Fi)  \
# 0                      20.0                         21
# 1                      20.0                         43
# 2                      20.0                         62
# 3                      20.0                         85
# 4                      20.0                        100
#
#    Frecuencia relativa (hi)  Frecuencia relativa acumulada (Hi)  \
# 0                      0.21                                0.21
# 1                      0.22                                0.43
# 2                      0.19                                0.62
# 3                      0.23                                0.85
# 4                      0.15                                1.00
#
#    (fi - FE)^2 / FE
# 0              0.05
# 1              0.20
# 2              0.05
# 3              0.45
# 4              1.25
#
# Estadístico Chi-cuadrada total: 2.0

# %%
# =========================
# HISTOGRAMAS
# =========================

# Histograma de frecuencias observadas
plt.hist(datos, bins=bins, edgecolor='black')
plt.title("Histograma de Frecuencias Observadas")
plt.xlabel("Intervalos")
plt.ylabel("Frecuencia")
plt.show()

# Histograma de frecuencias relativas
plt.hist(datos, bins=bins, density=True, edgecolor='black')
plt.title("Histograma de Frecuencias Relativas")
plt.xlabel("Intervalos")
plt.ylabel("Frecuencia Relativa")
plt.show()

# %% [markdown]
# que imprima si paso o no paso la prueba de frecuencia

# %% [markdown]
# Frecuencia esperada
