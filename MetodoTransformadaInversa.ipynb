# %% [markdown]
# <a href="https://colab.research.google.com/github/FOFM030711/Caminata-aleatoria-1D/blob/main/MetodoTransformadaInversa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
import numpy as np
import matplotlib.pyplot as plt

# %%
def triangular(n):
  l=[]
  for i in range(n):
    u=r.random()
    if 0 <= u < 0.5:
      x = np.sqrt(2*u)
      l.append(x)
    else:
      x = 2- np.sqrt(2*(1-u))
      l.append(x)
  return l

# %%
M= triangular(1000)

# %%
plt.hist(M,bins=50)
# Out:
# (array([ 2.,  4.,  5.,  4., 11.,  6., 12.,  9., 11., 21., 16., 14., 22.,
#          9., 25., 28., 25., 31., 32., 28., 30., 29., 41., 34., 35., 55.,
#         43., 32., 36., 26., 34., 26., 25., 22., 25., 23., 27., 19., 23.,
#         25., 14., 10., 11.,  6.,  8., 10., 10.,  2.,  3.,  1.]),
#  array([0.02301459, 0.06175219, 0.10048979, 0.13922739, 0.177965  ,
#         0.2167026 , 0.2554402 , 0.2941778 , 0.3329154 , 0.371653  ,
#         0.4103906 , 0.4491282 , 0.4878658 , 0.5266034 , 0.565341  ,
#         0.6040786 , 0.6428162 , 0.6815538 , 0.7202914 , 0.759029  ,
#         0.7977666 , 0.8365042 , 0.87524181, 0.91397941, 0.95271701,
#         0.99145461, 1.03019221, 1.06892981, 1.10766741, 1.14640501,
#         1.18514261, 1.22388021, 1.26261781, 1.30135541, 1.34009301,
#         1.37883061, 1.41756821, 1.45630581, 1.49504341, 1.53378101,
#         1.57251862, 1.61125622, 1.64999382, 1.68873142, 1.72746902,
#         1.76620662, 1.80494422, 1.84368182, 1.88241942, 1.92115702,
#         1.95989462]),
#  <BarContainer object of 50 artists>)

# %%
def cdf(M):
  n=len(M)
  x= np.sort(M)
  y= np.arange(0,n)/n
  return x,y

# %%
x_math,y_math=cdf(M)

# %%
media= np.mean(M)

# %%
plt.step(x_math,y_math)
plt.axhline( y=media, color='green')
plt.axhline(y=0.5, color='red')
