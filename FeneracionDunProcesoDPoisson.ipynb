# %% [markdown]
# <a href="https://colab.research.google.com/github/FOFM030711/Caminata-aleatoria-1D/blob/main/FeneracionDunProcesoDPoisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random as r
import matplotlib.pyplot as plt

# %%
def Poisson(lam,T):
  t=0
  S=[]
  I=0
  P=[]
  while t<=T:
    R=r.random()
    t = t - (1/lam) * np.log(R)
    I=I+1
    S.append(t)
    P.append(I)
  return S, P

# %%
L=Poisson(4,10)

# %%
L
# Out:
# ([np.float64(0.7761006098003373),
#   np.float64(1.0979797450778288),
#   np.float64(1.6263073711775147),
#   np.float64(1.8016266617930983),
#   np.float64(2.1249406153563477),
#   np.float64(2.1556168419480763),
#   np.float64(2.3013041143991924),
#   np.float64(2.3324302846038343),
#   np.float64(2.490290942499614),
#   np.float64(2.5820710202019637),
#   np.float64(2.786444099115749),
#   np.float64(3.193910802933955),
#   np.float64(3.6311016710323782),
#   np.float64(3.99338801082328),
#   np.float64(4.100312523639735),
#   np.float64(4.382646809247131),
#   np.float64(4.871328468902153),
#   np.float64(4.9584405047651945),
#   np.float64(5.592007258111157),
#   np.float64(6.197021948375129),
#   np.float64(6.208727248164112),
#   np.float64(6.508011945246205),
#   np.float64(6.578574044654976),
#   np.float64(6.984003039136412),
#   np.float64(7.364126895331134),
#   np.float64(7.39999558902827),
#   np.float64(7.779110775729143),
#   np.float64(8.06440954844489),
# ...

# %%
plt.step(L[0],L[1])

# %%
L[1][-1]#para ver quien llego al último
# Out:
# 34
